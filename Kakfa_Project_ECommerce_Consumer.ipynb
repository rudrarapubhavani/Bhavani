# %% [markdown]
# <a href="https://colab.research.google.com/github/rudrarapubhavani/Bhavani/blob/main/Kakfa_Project_ECommerce_Consumer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install confluent-kafka
import time
import json
from confluent_kafka import Consumer, KafkaError, KafkaException

# %%
config= {
    # Required connection configs for Kafka producer, consumer, and admin
     "bootstrap.servers" : "pkc-921jm.us-east-2.aws.confluent.cloud:9092",
"security.protocol" : "SASL_SSL",
"sasl.mechanisms" : "PLAIN",
"sasl.username" : "JT3RAJO4HX4HMTHL",
"sasl.password" : "cfltMcS9dkbK91VpwgkjPjnWqDRq9NJtvQqSnIuziXBy4R5h8FXUGa0rjxvbj21A",
    "session.timeout.ms" : 45000,

"client.id" : "ccloud-python-client-388dc123-79b2-4a8b-8048-f43d565f4947",
"auto.offset.reset" : "earliest",
    "group.id" : "python-group-1"


}

# %%
consumer= Consumer(config)

# %%
topic= 'E-Commerce'
consumer.subscribe([topic])

# %%
def ProcessingMessage(message):
  try:
    if message.error():
      if (message.error.code()== kafkaError._PARTOTION_EOF):
        print(f'End of partition reached {0}/ {1}')

      else:
        raise KafkaException(message.error)

    else:
      key= message.key().decode('utf-8')
      value= message.value().decode('utf-8')
      print(f'Message received key: {key}, Value: {value}')

  except Exception as e:
    print(f'Exception is {e}')


try:
  print('Listening for message Press CTRL+C to exit')
  while True:
    msg= consumer.poll(timeout=1.0)
    if msg:
      ProcessingMessage(msg)

except KeyboardInterrupt:
  print("Interrupted by user, Shutting down Consumer")
finally:
  consumer.close()
# Out:
# Streaming output truncated to the last 5000 lines.
# Message received key: -122.28, Value: {"longitude": -122.28, "latitude": 37.54, "housing_median_age": 37.0, "total_rooms": 991.0, "total_bedrooms": 180.0, "population": 463.0, "households": 177.0, "median_income": 5.1701, "median_house_value": 294200.0}
# Message received key: -122.28, Value: {"longitude": -122.28, "latitude": 37.54, "housing_median_age": 24.0, "total_rooms": 5114.0, "total_bedrooms": 1357.0, "population": 3169.0, "households": 1268.0, "median_income": 3.9699, "median_house_value": 293200.0}
# Message received key: -122.28, Value: {"longitude": -122.28, "latitude": 37.53, "housing_median_age": 34.0, "total_rooms": 1980.0, "total_bedrooms": 385.0, "population": 970.0, "households": 391.0, "median_income": 5.1207, "median_house_value": 310900.0}
# ...
